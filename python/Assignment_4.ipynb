# %% [markdown]
# 1.What exactly is []?

# %%
# in python [] this is a empty list

# %% [markdown]
# 2.In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam= [2, 4, 6, 8, 10]
#the value can assigned by using the index of third value
spam[2]='hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# 3.What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %%
spam=['a','b','c','d']

# int(3*2=33) ,int(33/11)=3,prints the value at the index value 3
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# 4.What is the value of spam[-1]?

# %%
#prints the last value of list spam
spam[-1]
# Out:
# 'd'

# %% [markdown]
# 5.What is the value of spam[:2]?

# %%
#prints the first 2 values of list at position of index 0,1
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# 6.What is the value of bacon.index(&#39;cat&#39;)?

# %%
bacon = [3.14, 'cat',11, 'cat', True]
#returns the index(position) value of cat which occurs first in the list
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# 7.How does bacon.append(99) change the look of the list value in bacon?

# %%
# this append 99 at last of position of the list
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8.How does bacon.remove('cat') change the look of the list in bacon?

# %%
# this will remove the cat from the list  which occurs first in list
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?

# %%
#The list concatenation operator in Python is the + operator and * is the replication operator
a=[1,2,3]
b=[4,5,6]
#concat
print("concat",a+b )
#replication
print("replicate",a*3)
# Out:
# concat [1, 2, 3, 4, 5, 6]
# replicate [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# 10.What is difference between the list methods append() and insert()?

# %%
lst=["a","b","c"]
# append()-will append the value at last of list
lst.append("d")
print("append()",lst)
#insert()-will insert the value at the specified index
lst.insert(0,"1")
print("insert()",lst)
# Out:
# append() ['a', 'b', 'c', 'd']
# insert() ['1', 'a', 'b', 'c', 'd']

# %% [markdown]
# 11. What are the two methods for removing items from a list?

# %%
#pop and remove are the two methods for removing items from a list

lst=["a","b","c","a"]
#pop -removes the element at the specified index from the list.
lst.pop(1)
print("pop(1)",lst)
#remove-removes the first occurrence of the specified value from the list.
lst.remove("a")
print("remove(a)",lst)
# Out:
# pop(1) ['a', 'c', 'a']
# remove(a) ['c', 'a']

# %% [markdown]
# 12. Describe how list values and string values are identical.

# %%
'''
Both list values and string values are sequences.
This means that they can be accessed using the index operator,
and they can be iterated over using a for loop.
'''
lst=["a","b","c"]
string="python"
print("acessing using index",lst[0],string[0])
# Out:
# acessing using index a p

# %% [markdown]
# 13. What&#39;s the difference between tuples and lists?

# %%
"""
List :

 Lists are mutable, can be changed after they are created.
 need to store more information about their contents.
 lists are slower

Tuple :

Tuples are immutable ,can not be change once tuple was created
Tuples typically use less memory than lists
Tuples are typically faster than lists
"""
#example of list
lst=[1,2,3]
#tupel
tple=(1,2,3)

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?

# %%
tup_42=(42,)
print(tup_42,type(tup_42))
# Out:
# (42,) <class 'tuple'>

# %% [markdown]
# 15.How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %%
# list can be converted to tuple using tuple()

lst=[1,2,3]
lst2tup = tuple(lst)
print("convert to tuple",lst2tup,type(lst2tup))

#tuple can be converted to list using list()

tup=(4,5,6)
tup2lst=list(tup)
print("convert to list",tup2lst,type(tup2lst))
# Out:
# convert to tuple (1, 2, 3) <class 'tuple'>
# convert to list [4, 5, 6] <class 'list'>

# %% [markdown]
# 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?

# %%
"""
Variables that "contain" list values are not necessarily lists themselves.
Instead, they contain references or pointers to lists

"""

lst = [1, 2, 3]

print(lst)

"""
list_value now contains a reference to the list [1, 2, 3]. If we were to print the value of the variable,
we would see the memory address of the list, not the actual list itself.
"""
# Out:
# [1, 2, 3]
# '\nlist_value now contains a reference to the list [1, 2, 3]. If we were to print the value of the variable,\nwe would see the memory address of the list, not the actual list itself.\n'

# %% [markdown]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
"""
copy.copy() function creates a shallow copy of an object.

If the original object is modified, the changes will be reflected in the copy.

"""
import copy
lst= ["a","b","c"]
copy_copy = copy.copy(lst)
lst[0] = 4
print(lst,copy_copy)

# deep copy

"""
copy.deepcopy() function creates a deep copy of an object.

If the original object is modified, the changes will not be reflected in the copy.

"""
deep_copy = copy.deepcopy(lst)
lst[0] = 5
print(lst,deep_copy)
# Out:
# [4, 'b', 'c'] ['a', 'b', 'c']
# [5, 'b', 'c'] [4, 'b', 'c']
